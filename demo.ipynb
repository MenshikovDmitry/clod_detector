# %%
import cv2
from matplotlib import pyplot as plt

from komok_detector import Komok_Detector

# %%
detector=Komok_Detector('mask_rcnn_komok.h5')

# %%
# %%time
image=cv2.imread('data/images/val/fonar_avi_315.jpg')
img = detector.detect(image)
# Out:
# CPU times: user 1.16 s, sys: 322 ms, total: 1.48 s
# Wall time: 1.11 s
